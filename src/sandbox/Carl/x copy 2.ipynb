# %%
import pandas as pd
from pipeline import create_X_y_df
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %%
df

# %%
# Out:
#    model_type   feature_set  n_features  threshold   roc_auc    pr_auc  \
# 0         xgb        static           7        0.5  0.564388  0.055414
# 1         hgb        static           7        0.5  0.564051  0.055453
# 2          rf        static           7        0.5  0.563017  0.054771
# 3          et        static           7        0.5  0.563219  0.054881
# 4      logreg        static           7        0.5  0.567437  0.055652
# ..        ...           ...         ...        ...       ...       ...
# 91        hgb  all_features          48        0.5  0.722433  0.128041
# 92         rf  all_features          48        0.5  0.709697  0.122904
# 93         et  all_features          48        0.5  0.699607  0.113739
# 94     logreg  all_features          48        0.5  0.722654  0.131402
# 95        svm  all_features          48        0.5  0.721668  0.130657
#
#     precision    recall        f1     tn     fp    fn    tp
# ...

# %%
df_full["recall"].max()
# Out:
# np.float64(0.6716038933559035)

# %%
df = df_full.copy()

# %%
#

df_cancel_user_id = d
