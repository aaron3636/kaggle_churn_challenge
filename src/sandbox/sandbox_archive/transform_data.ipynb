# %%
import pandas as pd

# %%
df_train = pd.read_parquet("1_Data/churn-prediction-25-26/train.parquet")

# %%
d = df_train.groupby("userId")["sessionId"].unique()

# %%
#print(d)


df_train["auth"].unique()
# Out:
# array(['Logged In', 'Cancelled'], dtype=object)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17499636 entries, 0 to 25661583
# Data columns (total 19 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   status         int64
#  1   gender         object
#  2   firstName      object
#  3   level          object
#  4   lastName       object
#  5   userId         object
#  6   ts             int64
#  7   auth           object
#  8   page           object
#  9   sessionId      int64
#  10  location       object
#  11  itemInSession  int64
#  12  userAgent      object
#  13  method         object
#  14  length         float64
#  15  song           object
#  16  artist         object
#  17  time           datetime64[us]
#  18  registration   datetime64[us]
# dtypes: datetime64[us](2), float64(1), int64(4), object(12)
# memory usage: 2.6+ GB

# %%
df_train["page"].unique()

"""
print(df_train[df_train["page"] == "Error"].count())
print(df_train[df_train["status"] == 404].count())
"""
df_train[(df_train["page"] != "Error") & \
    (df_train["status"] == 404)]
# Out:
# Empty DataFrame
# Columns: [status, gender, firstName, level, lastName, userId, ts, auth, page, sessionId, location, itemInSession, userAgent, method, length, song, artist, time, registration]
# Index: []

# %%
df_train.columns
# Out:
# Index(['status', 'gender', 'firstName', 'level', 'lastName', 'userId', 'ts',
#        'auth', 'page', 'sessionId', 'location', 'itemInSession', 'userAgent',
#        'method', 'length', 'song', 'artist', 'time', 'registration'],
#       dtype='object')
