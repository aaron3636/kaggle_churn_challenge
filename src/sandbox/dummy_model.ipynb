# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate, train_test_split
from sklearn.pipeline import make_pipeline
import pandas as pd


from skrub import TableVectorizer

# %%
df_train = pd.read_parquet("../../data/churn-prediction-25-26/train.parquet")

# %%
df_train.columns

# %%
df_train["target"] = df_train["page"] == "Cancellation Confirmation"

df_train["target"] = df_train["target"].astype("int")

df_train_all = df_train.copy()

# %%
df_train = df_train.drop(df_train[df_train["page"] == "Cancellation Confirmation"].index)

# %%
df_train[["target"]]
# Out:
#           target
# 0              0
# 992            0
# 1360           0
# 1825           0
# 2366           0
# ...          ...
# 25661184       0
# 25661214       0
# 25661320       0
# 25661462       0
# 25661583       0
#
# [17495365 rows x 1 columns]

# %%
given_columns = ['status', 'gender', 'firstName', 'level', 'lastName', 'userId', 'ts',
       'auth', 'page', 'sessionId', 'location', 'itemInSession', 'userAgent',
       'method', 'length', 'song', 'artist', 'time', 'registration']


model = make_pipeline(
    TableVectorizer(),
    LogisticRegression(max_iter=10000, fit_intercept=True)
)

X_train, X_test, y_train, y_test = train_test_split(df_train[given_columns], df_train[["target"]])

#cross_validate(lr, df_train[given_columns], df_train[["target"]], error_score=True)

# %%
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model.fit(X_train, y_train)
#
# File ~/anaconda3/envs/pfds/lib/python3.10/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/pfds/lib/python3.10/site-packages/sklearn/pipeline.py:655, in Pipeline.fit(self, X, y, **params)
#     648     raise ValueError(
#     649         "The `transform_input` parameter can only be set if metadata "
#     650         "routing is enabled. You can enable metadata routing using "
# ...
