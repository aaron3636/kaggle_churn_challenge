# %%
import pandas as pd
import pm4py

# %%
df_train = pd.read_parquet("1_Data/churn-prediction-25-26/train.parquet")

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17499636 entries, 0 to 25661583
# Data columns (total 19 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   status         int64
#  1   gender         object
#  2   firstName      object
#  3   level          object
#  4   lastName       object
#  5   userId         object
#  6   ts             int64
#  7   auth           object
#  8   page           object
#  9   sessionId      int64
#  10  location       object
#  11  itemInSession  int64
#  12  userAgent      object
#  13  method         object
#  14  length         float64
#  15  song           object
#  16  artist         object
#  17  time           datetime64[us]
#  18  registration   datetime64[us]
# dtypes: datetime64[us](2), float64(1), int64(4), object(12)
# memory usage: 2.6+ GB

# %%
dataframe = df_train.rename(columns={'userId': 'case:userId'})
dataframe = pm4py.format_dataframe(dataframe, case_id='sessionId',
activity_key='page',
timestamp_key='time')

event_log = pm4py.convert_to_event_log(dataframe)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 6
#       1 dataframe = df_train.rename(columns={'userId': 'case:userId'})
#       2 dataframe = pm4py.format_dataframe(dataframe, case_id='sessionId',
#       3 activity_key='page',
#       4 timestamp_key='time')
# ----> 6 event_log = pm4py.convert_to_event_log(dataframe)
#
# File ~/anaconda3/envs/pfds/lib/python3.10/site-packages/pm4py/convert.py:82, in convert_to_event_log(obj, case_id_key, **kwargs)
#      78     parameters[k] = v
#      80 from pm4py.objects.conversion.log import converter
# ---> 82 log = converter.apply(
#      83     obj, variant=converter.Variants.TO_EVENT_LOG, parameters=parameters
#      84 )
#      86 __event_log_deprecation_warning(log)
#      88 return log
#
# ...
